# %% [markdown]
# <h1>Seaborn</h1>

# %%
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Heatmap</h1>

# %% [markdown]
# <p>Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred</p>

# %%
data = np.random.randint(1,100,(10,10)) #10 by 10 matrix of number between 1 and 100
data
# Out:
# array([[47,  2,  7, 96, 93, 63, 44,  4, 76, 66],
#        [38, 11, 88, 38, 48, 76, 63, 22, 45, 13],
#        [41, 82, 10, 75, 60,  4, 84, 55, 54, 90],
#        [68, 40, 78, 30, 48, 50, 28, 98, 91, 20],
#        [33, 89, 27, 89, 11, 30, 71, 62, 40,  6],
#        [80, 18, 17,  3, 34, 78, 55, 84, 37, 19],
#        [45, 50, 86, 17, 59, 58, 11, 72, 91, 24],
#        [28, 83,  6, 71, 69, 56, 25, 87, 75, 75],
#        [29, 84, 73, 50, 31, 25, 92, 75, 76, 51],
#        [39, 45, 33, 12, 14, 52, 84, 50, 41, 50]])

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h6>Anchoring the color map</h6>
# <p>If we set the vmin value to 30 and the vmax value to 70, then only the cells with values between 30 and 80 will be displayed. This is called anchoring the colormap</p>

# %%
#Numbers less than 30 will have blue color 
sns.heatmap(data,vmin=30,vmax=80,cmap='tab10',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h6>Choosing the colormap</h6>
# <p>In this, we will be looking at the cmap parameter. Matplotlib provides us with multiple colormaps, you can look at all of them <a href="https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html">here</a> </p>

# %%
sns.heatmap(data,cmap='tab10')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h6>Displaying the cell values</h6>

# %%
sns.heatmap(data,annot=True,cmap='tab20',vmin=30,vmax=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h3>Customizing the separating line</h3>
# <p>We can change the thickness and the color of the lines separating the cells using the linewidths and linecolor parameters respectively.</p>

# %%
sns.heatmap(data,annot=True,cmap='Set1',linewidths=2,linecolor='red')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data,annot=True,xticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Countplot</h1>
# <p>Countplot is used to Show the counts of observations in each categorical bin using bars.</p>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(df.sex)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(df.sex,hue=df['smoker'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(df.sex,hue=df['smoker'],palette='Set1')
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>
